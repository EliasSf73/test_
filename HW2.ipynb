# %% [markdown]
# <a href="https://colab.research.google.com/github/EliasSf73/test_/blob/master/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 2 (Full mark: 100pt)
# - Questions 1~3: Conceptual
# - Questions 4~6: Programming

# %% [markdown]
# # Conceptual questions

# %% [markdown]
# # 1. Logistic function (5pt)
# **Show how to derive the odds, i.e., $\frac{p(X)}{1-p(X)}=e^{\beta_{0}+\beta_{1} X}$, from the logistic function, i.e., $p(X)=\frac{e^{\beta_{0}+\beta_{1} X}}{1+e^{\beta_{0}+\beta_{1} X}}$.**
# ![1st.png](data:image/png;base64,...![2nd.png]())

# %%
from IPython.display import Image, display

display(Image(filename='/content/1st.png'))

# %% [markdown]
# # 2. Discriminant function (10pt)
# **Show that under the assumption that the observations in the $k$th class are drawn from a Gaussian distribution $N(\mu_k, \sigma^2)$, the Bayes’ classifier assigns an observation to the class for which the discriminant function is maximized. In other words, show that $\underset{k}{\arg \max } p_{k}(x)=\underset{k}{\arg \max } \delta_{k}(x)$, where $p_{k}(x)=\frac{\pi_{k} \frac{1}{\sqrt{2 \pi} \sigma} \exp \left(-\frac{1}{2 \sigma^{2}}\left(x-\mu_{k}\right)^{2}\right)}{\sum_{l=1}^{K} \pi_{l} \frac{1}{\sqrt{2 \pi} \sigma}  \exp \left(-\frac{1}{2 \sigma^{2}}\left(x-\mu_{l}\right)^{2}\right)}$ and $\delta_{k}(x)=x \cdot \frac{\mu_{k}}{\sigma^{2}}-\frac{\mu_{k}^{2}}{2 \sigma^{2}}+\log \left(\pi_{k}\right)$**

# %%
display(Image(filename='/content/2nd.png'))

# %% [markdown]
# # 3. LDA vs. QDA (20pt)
# **(a) If the Bayes decision boundary is linear, do we expect LDA or QDA to perform better on the training set? On the test set?**
#
# => ***On the training dataset: We would expect QDA to perform better on the training set because its increased
# flexiblity will result in a closer fit.
#
# ***=> On the test dataset:LDA tends to generalize better to new, unseen data when the boundary is truly linear because it sticks to the "straight path." It doesn't get distracted by the random fluctuations that might have happened just by chance in the training data. QDA might struggle because the extra complexity it used to get a perfect score on the training data could backfire***.
#
# **(b) If the Bayes decision boundary is non-linear, do we expect LDA or QDA to perform better on the training set? On the test set?**
#
# => ***If the Bayes decision boundary is non-linear, QDA is generally expected to outperform LDA because it is more flexible due to its ability to model curved decision boundaries.***
# ***-> On the training dataset: QDA can adapt its decision boundary to follow the non-linear contours of the data while LDA is limited to straight line.***
#
# ***-> On the test dataset: QDA should also generally perform better on the test set in scenarios where the decision boundary is indeed non-linear, provided that there is enough data to accurately estimate the parameters of the model and that the model isn't overfitting to the training data while LDA might not perform as well because it may miss important relationships in the data that only a non-linear boundary can capture***.
#
# **(c) In general, as the sample size $n$ increases, do we expect the test prediction accuracy of QDA relative to LDA to improve, decline, or be unchanged? Why?**
#
# => As the sample size n increases, we generally expect the test prediction accuracy of QDA relative to LDA to improve, assuming the true decision boundary is non-linear: which is kind of reasonable for large dataset.
#   #QDA relies on estimating more parameters than LDA because it allows for a unique covariance matrix for each class. With more data, the estimates of these parameters become more accurate, which means that QDA's model of the decision boundary can become more precise
#
#   #With small sample sizes, QDA's complexity can lead to overfitting—finding patterns that aren't actually there. As you get more data, the risk of overfitting decreases. ***bold text***
#
# **(d) True or False: Even if the Bayes decision boundary for a given problem is linear, we will probably achieve a superior test error rate using QDA rather than LDA because QDA is flexible enough to model a linear decision boundary. Justify your answer.**
#
# =>False
# -> With fewer sample points, the variance from using a more flexible method,
# such as QDA, would likely result in overfitting, yielding a higher test error rate than LDA. ***bold text***

# %% [markdown]
# # 4. Weekly dataset (25pt)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Weekly.csv')
df
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today Direction
# 0     1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270      Down
# 1     1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576      Down
# 2     1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514        Up
# 3     1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712        Up
# 4     1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178        Up
# ...    ...    ...    ...    ...    ...    ...       ...    ...       ...
# 1084  2010 -0.861  0.043 -2.173  3.599  0.015  3.205160  2.969        Up
# 1085  2010  2.969 -0.861  0.043 -2.173  3.599  4.242568  1.281        Up
# 1086  2010  1.281  2.969 -0.861  0.043 -2.173  4.835082  0.283        Up
# 1087  2010  0.283  1.281  2.969 -0.861  0.043  4.454044  1.034        Up
# 1088  2010  1.034  0.283  1.281  2.969 -0.861  2.707105  0.069        Up
#
# [1089 rows x 9 columns]

# %% [markdown]
# **(a) Produce some numerical and graphical summaries of the Weekly data. Do there appear to be any patterns? For numerical analyses, use ````pandas```` functions such as ````corr()```` and ````describe()````, and for graphical analyses use ````pairplot````, ````boxplot````, and ````scatterplot````.**

# %%
# Write your answer here
# df['Direction'] = df['Direction'].astype('category')
# df['Direction']=df['Direction'].cat.codes

df.iloc[:,:-1].corr(method='pearson',min_periods=1)
df.iloc[:,:-1].corr()
# Out:
#             Year      Lag1      Lag2      Lag3      Lag4      Lag5    Volume  \
# Year    1.000000 -0.032289 -0.033390 -0.030006 -0.031128 -0.030519  0.841942
# Lag1   -0.032289  1.000000 -0.074853  0.058636 -0.071274 -0.008183 -0.064951
# Lag2   -0.033390 -0.074853  1.000000 -0.075721  0.058382 -0.072499 -0.085513
# Lag3   -0.030006  0.058636 -0.075721  1.000000 -0.075396  0.060657 -0.069288
# Lag4   -0.031128 -0.071274  0.058382 -0.075396  1.000000 -0.075675 -0.061075
# Lag5   -0.030519 -0.008183 -0.072499  0.060657 -0.075675  1.000000 -0.058517
# Volume  0.841942 -0.064951 -0.085513 -0.069288 -0.061075 -0.058517  1.000000
# Today  -0.032460 -0.075032  0.059167 -0.071244 -0.007826  0.011013 -0.033078
#
#            Today
# Year   -0.032460
# Lag1   -0.075032
# Lag2    0.059167
# Lag3   -0.071244
# Lag4   -0.007826
# Lag5    0.011013
# Volume -0.033078
# Today   1.000000

# %% [markdown]
# ***Interpretation***:
#
# Strong Positive Correlation (0.841942): "Year" and "Volume" have a strong positive linear relationship. This suggests that as the "Year" increases, "Volume" also tends to increase in a proportional manner. The closer the correlation coefficient is to 1, the stronger the positive linear relationship, and 0.841942 is relatively close to 1, indicating a robust positive association.

# %%
df.iloc[:,:-1].describe()
# Out:
#               Year         Lag1         Lag2         Lag3         Lag4  \
# count  1089.000000  1089.000000  1089.000000  1089.000000  1089.000000
# mean   2000.048669     0.150585     0.151079     0.147205     0.145818
# std       6.033182     2.357013     2.357254     2.360502     2.360279
# min    1990.000000   -18.195000   -18.195000   -18.195000   -18.195000
# 25%    1995.000000    -1.154000    -1.154000    -1.158000    -1.158000
# 50%    2000.000000     0.241000     0.241000     0.241000     0.238000
# 75%    2005.000000     1.405000     1.409000     1.409000     1.409000
# max    2010.000000    12.026000    12.026000    12.026000    12.026000
#
#               Lag5       Volume        Today
# count  1089.000000  1089.000000  1089.000000
# mean      0.139893     1.574618     0.149899
# std       2.361285     1.686636     2.356927
# min     -18.195000     0.087465   -18.195000
# 25%      -1.166000     0.332022    -1.154000
# 50%       0.234000     1.002680     0.241000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df.iloc[:,:-1],diag_kind='kde')

# %%
for column in df.columns[:-1]:
  sns.boxplot(x='Direction',y=column,data=df)
  plt.title(f'boxlot of {column} vs Direction')
  plt.show()

# %%
for column in df.columns[:-1]:
  sns.scatterplot(y='Direction',x=column,data=df)
  plt.title(f'scatterplot of {column} vs Direction')
  plt.show()

# %% [markdown]
# ***Interpretation From BoxPlot:***
#
# =>The similarity in medians of "Volume" across the two Directions suggests that the "Volume" variable might not be a strong discriminator for the "Direction" response on its own. Both Directions show a median "Volume" around the same level, which means that, at least from the median perspective, "Volume" is not varying significantly with changes in "Direction".
#
# =>The difference in medians for "Today" across the two Directions suggests that there may be some relationship where "Today" can have some influence on "Direction" or vice versa

# %% [markdown]
# **(b) Fit the logistic regression model using a training data period from 1990 to 2008, with ````Lag2```` as the only predictor. Compute the confusion matrix and the overall fraction of correct predictions for the held out data (that is, the data from 2009 and 2010). Explain what the confusion matrix is telling you about the types of mistakes made by logistic regression.**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# Write your answer here
train_df = df[df['Year'] <= 2008]
test_df = df[df['Year'] > 2008]

X_train = train_df['Lag2'].values.reshape(-1, 1)
y_train = train_df['Direction'].values.reshape(-1,)
X_test = test_df['Lag2'].values.reshape(-1, 1)
y_test = test_df['Direction'].values.reshape(-1,)

log_model = LogisticRegression()
log_model.fit(X_train, y_train)
test_predictions = log_model.predict(X_test)

print('Accuracy:', log_model.score(X_test, y_test))
print('Fraction of Correct:', np.sum(test_predictions == y_test), '/', len(y_test))

conf_matrix = pd.DataFrame(confusion_matrix(y_test, test_predictions))
conf_matrix.columns.name = 'Predicted'
conf_matrix.index.name = 'True'
conf_matrix
# Out:
# Accuracy: 0.625
# Fraction of Correct: 65 / 104
# Predicted  0   1
# True
# 0          9  34
# 1          5  56

# %% [markdown]
# **(c) Repeat (b) using LDA (Compute the confusion matrix and the overall fraction of correct predictions for the held out data)**

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Write your answer here
LDA_model = LinearDiscriminantAnalysis()
LDA_model.fit(X_train, y_train)
test_predictions = LDA_model.predict(X_test)

print('Accuracy:', LDA_model.score(X_test, y_test))

conf_matrix = pd.DataFrame(confusion_matrix(y_test, test_predictions))
conf_matrix.columns.name = 'Predicted'
conf_matrix.index.name = 'True'
conf_matrix
# Out:
# Accuracy: 0.625
# Predicted  0   1
# True
# 0          9  34
# 1          5  56

# %% [markdown]
# **(d) Repeat (b) using QDA (Compute the confusion matrix and the overall fraction of correct predictions for the held out data)**

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# Write your answer here
QDA_model = QuadraticDiscriminantAnalysis()
QDA_model.fit(X_train, y_train)
test_predictions = QDA_model.predict(X_test)

print('Accuracy:', QDA_model.score(X_test, y_test))

conf_matrix = pd.DataFrame(confusion_matrix(y_test, test_predictions))
conf_matrix.columns.name = 'Predicted'
conf_matrix.index.name = 'True'
conf_matrix
# Out:
# Accuracy: 0.5865384615384616
# Predicted  0   1
# True
# 0          0  43
# 1          0  61

# %% [markdown]
# **(e) Repeat (b) using KNN with $K=1$ (Compute the confusion matrix and the overall fraction of correct predictions for the held out data)**

# %%
from sklearn.neighbors import KNeighborsClassifier

# Write your answer here
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(X_train, y_train)
test_predictions = knn_model.predict(X_test)

print('Accuracy:', knn_model.score(X_test, y_test))

conf_matrix = pd.DataFrame(confusion_matrix(y_test, test_predictions))
conf_matrix.columns.name = 'Predicted'
conf_matrix.index.name = 'True'
conf_matrix
# Out:
# Accuracy: 0.49038461538461536
# Predicted   0   1
# True
# 0          22  21
# 1          32  29

# %% [markdown]
# # 5. Multi-class Classification (One-vs-the-rest and one-vs-one) (20pt)

# %% [markdown]
# **Build a classification model to classify the class of iris plant. For this, use ````sklearn.multiclass.OneVsOneClassifier```` and ````sklearn.multiclass.OneVsRestClassifier````. You are free to choose any classifier of your choice. Use train-test split of 80%:20%. Implement both one-vs-the-rest and one-vs-one.**
#
# **[Tips] You may also import train_test_split if it helps.**

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split

df = pd.read_csv('iris.csv')
df['class'] = pd.factorize(df['class'])[0]
no_label = [col for col in df.columns if col != 'class']
new_df = df[no_label]

# Write your answer here
X_train, X_test, y_train, y_test = train_test_split(new_df, df['class'], test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
clf_model = LogisticRegression()
one_vs_one_model = OneVsOneClassifier(clf_model)
one_vs_rest_model = OneVsRestClassifier(clf_model)

one_vs_one_model.fit(X_train, y_train)
one_vs_rest_model.fit(X_train, y_train)

one_vs_one_score = one_vs_one_model.score(X_test, y_test)
one_vs_rest_score = one_vs_rest_model.score(X_test, y_test)

print('Classification Model used:', clf_model)
print('Accuracy of One VS One:', one_vs_one_score)
print('Accuracy of One VS Rest:', one_vs_rest_score)
# Out:
# Classification Model used: LogisticRegression()
# Accuracy of One VS One: 1.0
# Accuracy of One VS Rest: 0.9666666666666667

# %% [markdown]
# # 6. Newton's Method (20pt)

# %% [markdown]
# **In Lecture 3, we learned about Newton's method and two different perspectives of deriving the Newton's method. For this question, implement Newton's method.**
#
# **[Tips] If you're unable to invert the Hessian Matrix due to it being singular, consider adding very small constants to the diagonal elements of the Hessian matrix.**

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
from scipy.stats import logistic # Logistic function
import matplotlib.pyplot as plt

# load data
caravan = pd.read_csv('Caravan.csv', index_col=0)
caravan.Purchase = caravan.Purchase.astype('category')

X = caravan.iloc[:, 0:85].values

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

X = sm.add_constant(X)
y = caravan.Purchase.factorize()[0]

X_train = X[1001:]
y_train = y[1001:]
X_test = X[:1000]
y_test = y[:1000]

beta = np.random.rand(X.shape[1])
epochs = 20  # The number of iterations to perform gradient descent
n = float(len(X_train)) # Number of elements in X

cost = []

# Performing Newton's method
######################## Write your answere here ########################
beta *= 1e-15
for epoch in range(epochs):
    y_train_pred = logistic.cdf(X_train @ beta)
    cross_entropy = (-1/n) * np.sum(y_train * np.log(y_train_pred + 1e-15) + (1 - y_train) * np.log(1 - y_train_pred + 1e-15))
    dbeta = (1/n) * (X_train.T @ (y_train_pred - y_train))
    sig_deriv = y_train_pred * (1 - y_train_pred)
    diagon_sig_deriv = np.diag(sig_deriv)
    second_dbeta = np.linalg.inv((1/n) * (X_train.T @ (diagon_sig_deriv @ X_train) + 1e-15))
    beta = beta - (second_dbeta @ dbeta)
    cost.append(cross_entropy)

#########################################################################

plt.plot(np.arange(epochs), cost)
plt.title("Learning curve")
plt.xlabel("Epoch")
plt.ylabel(r"J($\beta$)");
y_test_pred = logistic.cdf(np.dot(X_test, beta)) > 0.5 # 0.5 should be fixed.
acc = accuracy_score(y_test, y_test_pred)
print("Accuracy of Logistic Regression (Newton's method): {}".format(acc))
# Out:
# Accuracy of Logistic Regression (Newton's method): 0.934
